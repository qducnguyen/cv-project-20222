# %% [markdown]
# # Debug Dataset

# %%
from RUSH_CV.Base.SRDataset import SRDataset
from RUSH_CV.Dataset.PexelsFlowers import PexelsFlowers

# %%
np.random.seed(1000)


train_dataset = PexelsFlowers(data_np_path=f'data/preprocess/pexels_flowers_train_x4.npy',
                                    patch_size=1024,
                                    is_train=True,
                                    is_pre_scale=False,
                                    scale=4)

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(1000)

_, data_1, data_2 =  train_dataset[1]



plt.imshow(data_1.permute(1, 2 ,0).numpy())

# %%
plt.imshow(data_2.permute(1, 2 ,0).numpy())

# %%
dataset_test[0][2]
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
import cv2
img = cv2.cvtColor(cv2.imread('data/pexels-flowers/train_LR/x4/0001x4.png'), cv2.COLOR_RGB2BGR)    
img
# Out:
# array([[[190, 169, 156],
#         [192, 174, 164],
#         [195, 179, 168],
#         ...,
#         [159, 145, 103],
#         [157, 143, 103],
#         [154, 142, 101]],
#
#        [[189, 170, 159],
#         [191, 173, 163],
#         [195, 180, 167],
#         ...,
#         [160, 143, 106],
#         [156, 144, 106],
#         [156, 141,  99]],
#
#        [[189, 170, 155],
#         [191, 174, 162],
#         [196, 179, 166],
#         ...,
#         [163, 148, 107],
#         [161, 145, 107],
#         [160, 144, 105]],
#
#        ...,
#
#        [[ 77,  63,  42],
#         [ 79,  65,  44],
#         [ 84,  68,  41],
#         ...,
#         [118,  23,  24],
#         [117,  22,  25],
#         [118,  23,  24]],
#
#        [[ 78,  63,  40],
#         [ 80,  65,  41],
#         [ 86,  67,  42],
#         ...,
#         [111,  19,  21],
#         [109,  21,  21],
#         [106,  20,  22]],
#
#        [[ 80,  62,  40],
#         [ 79,  65,  40],
#         [ 83,  67,  40],
#         ...,
#         [104,  17,  19],
#         [102,  18,  20],
#         [101,  16,  19]]], dtype=uint8)

# %%
img[3: 3 + 75, 4 + 4: 75, :]
# Out:
# array([[[205, 191, 182],
#         [206, 192, 185],
#         [207, 192, 185],
#         ...,
#         [192, 176, 149],
#         [193, 177, 154],
#         [196, 179, 158]],
#
#        [[204, 189, 177],
#         [203, 194, 181],
#         [206, 192, 181],
#         ...,
#         [191, 174, 150],
#         [192, 176, 153],
#         [194, 177, 155]],
#
#        [[203, 188, 176],
#         [203, 190, 180],
#         [204, 191, 180],
#         ...,
#         [189, 173, 144],
#         [191, 173, 148],
#         [194, 177, 151]],
#
#        ...,
#
#        [[ 77,  70,  20],
#         [ 80,  71,  19],
#         [ 79,  72,  20],
#         ...,
#         [206, 190, 171],
#         [204, 190, 171],
#         [205, 186, 168]],
#
#        [[ 79,  70,  22],
#         [ 76,  70,  22],
#         [ 81,  70,  21],
#         ...,
#         [206, 191, 175],
#         [205, 191, 173],
#         [205, 189, 169]],
#
#        [[ 80,  70,  20],
#         [ 78,  69,  20],
#         [ 78,  71,  21],
#         ...,
#         [208, 193, 176],
#         [206, 192, 171],
#         [207, 192, 173]]], dtype=uint8)

# %%
cv2.resize(img[3: 3 + 75, 4 + 4: 75, :], None, fx=4, fy=4, interpolation=cv2.INTER_CUBIC).shape
# Out:
# (300, 268, 3)

# %%
from RUSH_CV.Dataset.PexelsFlowers import PexelsFlowers

# %%
test = PexelsFlowers(data_np_path='data/preprocess/pexels_flowers_train_x4.npy',
                     patch_size=192,
                     is_train=True,
                     is_pre_scale=True,
                     scale=4)

# %%
valid_dataset = PexelsFlowers(data_np_path='data/preprocess/pexels_flowers_valid_x4.npy',
                                   patch_size=64,
                                    is_train=False,
                                    is_pre_scale=True,
                                    scale=4)

# %%
import numpy as np
img_list = np.load('data/preprocess/pexels_flowers_valid_x4.npy')

# %%
import cv2
cv2.imread('data/pexels-flowers/train_LR/x4/0001x4.png').shape
# Out:
# (339, 510, 3)

# %%
_, _ , _, X_patch, Y_patch, X_channel, Y_channel = test[0]

# %%
Y_channel.shape
# Out:
# (192, 192, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(Y_patch)

# %% [markdown]
# # Debug Models

# %% [markdown]
# ## VDSR

# %%
from RUSH_CV.Network.VDSR import VDSR

# %%
model = VDSR(num_channels=3, base_channels=64, num_residuals=6)

# %%
model.weight_init()
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
